# %%
import rpy2.robjects as ro #rpy2 library is installed in python now

# Expand Java memory
ro.r('options(java.parameters = "-Xmx8g")')
# Out:
# <rpy2.robjects.vectors.ListVector object at 0x7f3c436be010> [19]
# R classes: ('list',)
# [StrSexpVector]
#   java.parameters: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#   <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7f3c436be1d0> [16]

# %%
ro.r('version')
# Out:
# <rpy2.robjects.vectors.ListVector object at 0x7f3c3406a050> [19]
# R classes: ('simple.list',)
# [StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe..., ..., StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe...]
#   platform: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f3c3406b590> [16]
# R classes: ('character',)
# ['x86_64-conda-linux-gnu']
#   arch: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f3c3406b610> [16]
# R classes: ('character',)
# ['x86_64']
#   os: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f3c3406add0> [16]
# R classes: ('character',)
# ['linux-gnu']
#   system: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f3c4350c550> [16]
# R classes: ('character',)
# ['x86_64, linux-gnu']
# ...
#   major: <class 'rpy2.robjects.vectors.StrVector'>
# ...
